# %%
import requests
print("Python Requests module - version:", requests.__version__)
print("Licence:", requests.__license__)
print("Copyright:",requests.__copyright__)
print("Author:",requests.__author__)
print("Document url, title, description:")
print(requests.__url__)
print(requests.__title__)
print(requests.__description__)
# Out:
# Python Requests module - version: 2.24.0
# Licence: Apache 2.0
# Copyright: Copyright 2020 Kenneth Reitz
# Author: Kenneth Reitz
# Document url, title, description:
# https://requests.readthedocs.io
# requests
# Python HTTP for Humans.

# %%
res = requests.get('https://google.com/')
print("Response of https://google.com/:")
print(res.status_code)
res1 = requests.get('https://w3resource.com/')
print("Response of https://w3resource.com/:")
print(res1.status_code)
print("\nMethods and attributes available to objects on successful\nrequest of https://w3rsource.com:\n")
print(dir(res))
# Out:
# Response of https://google.com/:
# 200
# Response of https://w3resource.com/:
# 200
#
# Methods and attributes available to objects on successful
# request of https://w3rsource.com:
#
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']

# %%
res = requests.post('https://google.com/')
print("Response of https://google.com/:")
print(res.status_code)
res1 = requests.post('https://w3resource.com/')
print("Response of https://w3resource.com/:")
print(res1.status_code)
print("\nMethods and attributes available to objects on successful\nrequest of https://w3rsource.com:\n")
print(dir(res))
# Out:
# Response of https://google.com/:
# 405
# Response of https://w3resource.com/:
# 200
#
# Methods and attributes available to objects on successful
# request of https://w3rsource.com:
#
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']

# %%
print(res1.__attrs__)
# Out:
# ['_content', 'status_code', 'headers', 'url', 'history', 'encoding', 'reason', 'cookies', 'elapsed', 'request']

# %%
print(res1.content)
# Out:
# b'\xef\xbb\xbf<!DOCTYPE html>\n\n<html lang="en">\n<head>\n\n<meta charset="utf-8">\n<link type="text/css" rel="stylesheet" href="/assets/mdl/material.min.css">\n<link type="text/css" rel="stylesheet" href="/assets/mdl/additional.css">\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0">\n<link rel="shortcut icon" href="//www.w3resource.com/images/favicon.png">\n<title>Web development tutorials | w3resource</title>\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0">\n<meta name="description" content="Web development tutorials on HTML, CSS, JS, PHP, SQL, MySQL, PostgreSQL, MongoDB, JSON and more.">\n<meta property="og:title" content="web development tutorials from w3resource" />\n<meta property="og:description" content="Web development tutorials on HTML, CSS, JS, PHP, SQL, MySQL, PostgreSQL, MongoDB, JSON and more." />\n<meta property="og:type" content="tutorial" />\n<meta property="
# ...

# %%
res2 = requests.get('https://api.github.com/events', stream=True)
print(res2.raw)
print(res2.raw.read(15))
# Out:
# ...
# b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xed}[\x8f\xe4'

# %%
import pandas as pd
data = pd.read_csv("C:\\Users\\LylionCj\\Desktop\\iris.csv")
print("shape of the data:")
print(data.shape)
print("\nData Type:")
print(type(data))
print("\nFirst 3 rows:")
print(data.head(3))
# Out:
# shape of the data:
# (150, 5)
#
# Data Type:
# <class 'pandas.core.frame.DataFrame'>
#
# First 3 rows:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa

# %%
# print headers information and parse data
res3 = requests.get('https://api.github.com/')
response = res3.headers
print('Header information of the said response:')
print(response)
# Out:
# Header information of the said response:
# ...

# %%
print("status:", res3.headers['X-Github-Request-Id'])
# Out:
# status: FDEA:0F16:5A6C7C:6518B3:62A30FC9

# %%
res4 = res3.json()
print("JSON value of the said response:")
print(res3.json())
# Out:
# JSON value of the said response:
# ...

# %%
print("\nEach key of the response:")
print("Current user url:",res4['current_user_url'])
print("Current Followers url:", res4['followers_url'])
# Out:
# Each key of the response:
# Current user url: https://api.github.com/user
# Current Followers url: https://api.github.com/user/followers

# %%
# timeout one request after given seconds and raise exception 

print("timeout=0.001")

try:
    r = requests.get('https://github.com/',timeout=0.001)
    print(r.text)
    
except requests.exceptions.RequestException as e:
    print(e)

except requests.exceptions.HTTPError as e3:
    print("Please check network connection status code")

except requests.exceptions.TooManyRedirects as e1:
    print("Please try another URL")
    
except requests.exceptions.ConnectionError as e2:
    print("Please check your DNS connection for DNS connection failure and refused connections issue")
    
print("\ntimeout = 1.0 ")

try:
    r = requests.get('https://github.com/',timeout=1.0)
    print("Connected...!")
except requests.exceptions.RequestException as e:
    print(e)
# Out:
# timeout=0.001
# HTTPSConnectionPool(host='github.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000018CCD6FD280>, 'Connection to github.com timed out. (connect timeout=0.001)'))
#
# timeout = 1.0
# Connected...!

# %%
# send some sort of data in the URL query string 
payload = {'key1':'value1', 'key2':'value2'}
print("Parameters:", payload)
r = requests.get('https://httpbin.org/get', params=payload)
print("Print the url to check the URL has been correctly encoded or not!")
print(r.url)

print("\nPass a list of items as a value:")
payload = {'key1':'value','key2':['value2','value3']}
print("Parameters:", payload)
r1 = requests.get('https://httpbin.org/get', params = payload)
print("Print the url to check the URL has been correctly encoded or not!")
print(r1.url)
# Out:
# Parameters: {'key1': 'value1', 'key2': 'value2'}
# Print the url to check the URL has been correctly encoded or not!
# https://httpbin.org/get?key1=value1&key2=value2
#
# Pass a list of items as a value:
# Parameters: {'key1': 'value', 'key2': ['value2', 'value3']}
# Print the url to check the URL has been correctly encoded or not!
# https://httpbin.org/get?key1=value&key2=value2&key2=value3

# %%
# send cookies to a given server and access cookies from the response of a server 
url2= 'http://httpbin.org/cookies'
my_cookies = dict(cookies_are='cookies parameter use to send cookies to the server')
r = requests.get(url2,cookies=my_cookies)
print(r.text)
# Out:
# {
#   "cookies": {
#     "cookies_are": "cookies parameter use to send cookies to the server"
#   }
# }

# %%
# code to verify the ssl certificate for a website which is certified 
res4 = requests.get('https://rigaux.org/', verify=False)
print(res4)
res5 = requests.get('https://google.com/')
print(res5)
res6 = requests.get('https://rigaux.org',verify=True)
print(res6)
# Out:
# C:\Users\LylionCj\anaconda3\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'rigaux.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# <Response [200]>
# <Response [200]>
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ...
